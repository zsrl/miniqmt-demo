# %% [markdown]
# # 下载板块列表

# %%
from xtquant import xtdata

xtdata.download_sector_data()

# %% [markdown]
# # 获取板块列表

# %%
from xtquant import xtdata

res = xtdata.get_sector_list()

print(res)
# Out:
# ['上期所', '上证A股', '上证B股', '上证期权', '上证转债', '中金所', '创业板', '大商所', '板块交易指数', '板块加权交易指数', '板块加权指数', '板块指数', '沪市ETF', '沪市债券', '沪市基金', '沪市指数', '沪深A股', '沪深B股', '沪深ETF', '沪深债券', '沪深基金', '沪深指数', '沪深转债', '沪港通', '深市ETF', '深市债券', '深市基金', '深市指数', '深港通', '深证A股', '深证B股', '深证期权', '深证转债', '科创板', '科创板CDR', '证监会行业板块交易指数', '证监会行业板块指数', '迅投一级行业板块交易指数', '迅投一级行业板块加权交易指数', '迅投一级行业板块加权指数', '迅投一级行业板块指数', '迅投三级行业板块交易指数', '迅投三级行业板块加权交易指数', '迅投三级行业板块加权指数', '迅投三级行业板块指数', '迅投二级行业板块交易指数', '迅投二级行业板块加权交易指数', '迅投二级行业板块加权指数', '迅投二级行业板块指数', '连续合约', '郑商所', '香港联交所指数', '香港联交所股票', 'ETF主题指数', 'ETF债券型', 'ETF商品型', 'ETF股票型', 'ETF行业指数', 'ETF货币型', 'ETF跨境型', 'TGN3D打印', 'TGN5G', 'TGN6G概念', 'TGNAI PC', 'TGNAIGC概念', 'TGNAI手机', 'TGNAI语料', 'TGNBC电池', 'TGNC2M概念', 'TGNChatGPT概念', 'TGNCRO概念', 'TGNDRGDIP', 'TGNEDR概念', 'TGNERP概念', 'TGNETC', 'TGNF5G概念', 'TGNHJT电池', 'TGNMCU芯片', 'TGNMicroLED概念', 'TGNMiniLED', 'TGNMLOps概念', 'TGNMR（混合现实）', 'TGNMSCI概念', 'TGNNFT概念', 'TGNNMN概念', 'TGNOLED', 'TGNPCB概念', 'TGNPEEK材料', 'TGNPET铜箔', 'TGNPM2.5', 'TGNPOE胶膜', '
# ...

# %% [markdown]
# # 获取沪深A股

# %%
from xtquant import xtdata

xtdata.connect(port=58609)

res = xtdata.get_stock_list_in_sector('沪深指数')

print(res)
# Out:
# ***** xtdata连接成功 *****
# 服务信息: {'tag': 'xtquant', 'version': '1.0'}
# 服务地址: 127.0.0.1:58609
# 数据路径: d:\Code\course\miniqmt-demo\data\datadir
# 设置xtdata.enable_hello = False可隐藏此消息
#
# ...

# %% [markdown]
# # 下载指数权重

# %%
from xtquant import xtdata

xtdata.download_index_weight()

# %% [markdown]
# # 获取指数成分股权重

# %%
from xtquant import xtdata

res = xtdata.get_index_weight('000300.SH')

print(res)
# Out:
# {'000001.SZ': 0.569, '000002.SZ': 0.342, '000063.SZ': 0.497, '000069.SZ': 0.074, '000100.SZ': 0.489, '000157.SZ': 0.227, '000166.SZ': 0.224, '000301.SZ': 0.149, '000333.SZ': 1.761, '000338.SZ': 0.505, '000408.SZ': 0.139, '000425.SZ': 0.251, '000538.SZ': 0.254, '000568.SZ': 0.757, '000596.SZ': 0.237, '000617.SZ': 0.081, '000625.SZ': 0.465, '000651.SZ': 0.987, '000661.SZ': 0.217, '000708.SZ': 0.085, '000725.SZ': 0.848, '000733.SZ': 0.117, '000768.SZ': 0.168, '000776.SZ': 0.22, '000786.SZ': 0.16, '000792.SZ': 0.486, '000800.SZ': 0.047, '000858.SZ': 1.661, '000876.SZ': 0.12, '000877.SZ': 0.066, '000895.SZ': 0.152, '000938.SZ': 0.277, '000963.SZ': 0.152, '000977.SZ': 0.246, '000983.SZ': 0.131, '000999.SZ': 0.114, '001289.SZ': 0.016, '001979.SZ': 0.191, '002001.SZ': 0.144, '002007.SZ': 0.123, '002027.SZ': 0.368, '002049.SZ': 0.246, '002050.SZ': 0.296, '002074.SZ': 0.121, '002129.SZ': 0.213, '002142.SZ': 0.456, '002179.SZ': 0.203, '002180.SZ': 0.13, '002202.SZ': 0.116, '002230.SZ': 0.503, '
# ...

# %% [markdown]
# # 获取证券类型

# %%
from xtquant import xtdata

res1 = xtdata.get_instrument_type('600519.SH')
res2 = xtdata.get_instrument_type('000300.SH')
print(res1)
print(res2)

# %% [markdown]
# # 获取证券详情

# %%
from xtquant import xtdata

res = xtdata.get_instrument_detail('600000.SH')

res
